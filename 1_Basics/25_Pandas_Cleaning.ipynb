# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/1_Basics/25_Pandas_Cleaning.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Pandas Cleaning

# %% [markdown]
# Load in the data.

# %%
# Install datasets Library (if not already installed)
# !pip install -U datasets

# Importing Libraries
import pandas as pd
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %% [markdown]
# ## Date and Time

# %% [markdown]
# ### Datetime
#
# #### Notes
#
# * `pd.to_datetime()`: Convert argument to datetime.
#
# #### Example
#
# In our DataFrame the `job_posted_date` is actually a string not a datetime format. First let's convert it to datetime format.
#
# We'll also use `info()` to check if the data type changed from a string to a `datetime` format.

# %%
# Convert 'job_posted_date' to datetime without specifying the exact format
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'], errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %% [markdown]
# ### Date
#
# #### Notes
#
# * `dt`: accessor that provides a way to access specialized methods and properties we use to work with datatime data within a pandas series.
# * `date`: extract the date component from the datetime object in the series.
# * Use together `dt.date` on our series.
#
# #### Example
#
# Now let's turn it from a datetime to a date using `dt.date`.

# %%
df['job_posted_date'].dtype
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'], errors='coerce')
df['job_posted_date'].dtype
df['job_posted_date'].dt.year


df['job_posted_date'].dt.month_name()

df[df['job_posted_date'].dt.month_name() == 'January']
df[df['job_posted_date'] >= '2023-06-01']
# Out:
#               job_title_short  \
# 0        Senior Data Engineer
# 2               Data Engineer
# 3               Data Engineer
# 4               Data Engineer
# 5               Data Engineer
# ...                       ...
# 785686       Business Analyst
# 785696  Senior Data Scientist
# 785698          Data Engineer
# 785701          Data Engineer
# 785706          Data Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# 5                                       GCP Data Engineer
# ...                                                   ...
# 785686                                   Business Analyst
# 785696                          Senior Analytics Engineer
# 785698      Data Engineer, Gerencia Business Intelligence
# 785701      Data Engineer, Gerencia Business Intelligence
# 785706                               Junior Data Engineer
#
#                      job_location  \
# 0                   Watertown, CT
# 2                 Berlin, Germany
# 3                 San Antonio, TX
# 4                  Washington, DC
# 5                        Anywhere
# ...                           ...
# 785686                      Egypt
# 785696  Colombia, Huila, Colombia
# 785698          Las Condes, Chile
# 785701            Santiago, Chile
# 785706                 Lima, Peru
#
#                                               job_via  \
# 0                                     via Work Nearby
# 2                                        via LinkedIn
# 3                                   via Diversity.com
# 4                                  via Clearance Jobs
# 5                                    via ZipRecruiter
# ...                                               ...
# 785686                           via Jobs Trabajo.org
# 785696  via Trabajo.org - Vacantes De Empleo, Trabajo
# 785698  via Trabajo.org - Vacantes De Empleo, Trabajo
# 785701  via Trabajo.org - Vacantes De Empleo, Trabajo
# 785706  via Trabajo.org - Vacantes De Empleo, Trabajo
#
#                job_schedule_type  job_work_from_home       search_location  \
# 0                      Full-time               False  Texas, United States
# 2                      Full-time               False               Germany
# 3                      Full-time               False  Texas, United States
# 4                      Full-time               False                 Sudan
# 5       Contractor and Temp work                True               Georgia
# ...                          ...                 ...                   ...
# 785686                 Full-time               False                 Egypt
# 785696                 Full-time               False              Colombia
# 785698                 Full-time               False                 Chile
# 785701                 Full-time               False                 Chile
# 785706                 Full-time               False                  Peru
#
#        job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0           2023-06-16                  False                 False
# 2           2023-10-10                  False                 False
# 3           2023-07-04                   True                 False
# 4           2023-08-07                  False                 False
# 5           2023-11-07                  False                 False
# ...                ...                    ...                   ...
# 785686      2023-11-20                  False                 False
# 785696      2023-10-23                   True                 False
# 785698      2023-08-09                   True                 False
# 785701      2023-08-09                   True                 False
# 785706      2023-11-08                   True                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# 5       United States        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785686          Egypt        None              NaN              NaN
# 785696       Colombia        None              NaN              NaN
# 785698          Chile        None              NaN              NaN
# 785701          Chile        None              NaN              NaN
# 785706           Peru        None              NaN              NaN
#
#                         company_name  \
# 0               Boehringer Ingelheim
# 2           ALPHA Augmented Services
# 3       Southwest Research Institute
# 4                    Kristina Daniel
# 5                    smart folks inc
# ...                              ...
# 785686                       Sumerge
# 785696       Recruiting From Scratch
# 785698              Falabella Retail
# 785701              Falabella Retail
# 785706                       Emprego
#
#                                                job_skills  \
# 0                                                    None
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# 5                                ['python', 'sql', 'gcp']
# ...                                                   ...
# 785686                                               None
# 785696                                            ['sql']
# 785698             ['sql', 'python', 'gcp', 'aws', 'git']
# 785701             ['sql', 'python', 'gcp', 'aws', 'git']
# 785706             ['python', 'sql', 'azure', 'power bi']
#
#                                           job_type_skills
# 0                                                    None
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# 5       {'cloud': ['gcp'], 'programming': ['python', '...
# ...                                                   ...
# 785686                                               None
# 785696                           {'programming': ['sql']}
# 785698  {'cloud': ['gcp', 'aws'], 'other': ['git'], 'p...
# 785701  {'cloud': ['gcp', 'aws'], 'other': ['git'], 'p...
# 785706  {'analyst_tools': ['power bi'], 'cloud': ['azu...
#
# [450234 rows x 17 columns]

# %% [markdown]
# #### Note: For the rest of the time we're loading the data in we'll be automatically turn the `job_posted_date` column into a datetime object.

# %% [markdown]
# ## Sorting Values
#
# ### Notes
#
# * `sort_values()` sorts a DataFrame or a specific column in ascending or descending order based on one or more columns.
# * Typically this is used to sort by a specific column/s.
# * Parameters:
#     * `by` - column name or list of column names to sort by
#     * `ascending` - boolean or list of booleans, default `True`, to sort by descending you would use `False`
#     * `inplace` - whether to modify the DataFrame in place or return a new one
#
# ### Example
#
# Let's sort our DataFrame by the `job_posted_date` in descending order (from most recent date to least).

# %%
df.sort_values(by='job_posted_date', ascending=False, inplace=True)

df.sort_values(
    by=['job_posted_date', 'salary_year_avg'],
    ascending=[False, False]
)


df
# Out:
#               job_title_short  \
# 287457   Senior Data Engineer
# 129618  Senior Data Scientist
# 523498           Data Analyst
# 114666   Senior Data Engineer
# 696752          Data Engineer
# ...                       ...
# 341389         Data Scientist
# 70991           Data Engineer
# 542527         Data Scientist
# 137492          Data Engineer
# 347766          Data Engineer
#
#                                                 job_title  \
# 287457                               Senior Data Engineer
# 129618   Analytics Engineer - Specialist / Sr. Specialist
# 523498                         Data Analyst Transport F/H
# 114666                      Senior Data Engineer (Python)
# 696752                            Senior Data Engineer II
# ...                                                   ...
# 341389  Data Analytics Specialist (Up 6,500 / Oracle /...
# 70991                       IT Data Engineering – Manager
# 542527                            Data Science Consultant
# 137492                  Data Engineer - Customer Insights
# 347766                    Manager, Data Engineering, SMAI
#
#                              job_location                           job_via  \
# 287457             Randburg, South Africa                via CareerJunction
# 129618         Mumbai, Maharashtra, India               via Jobs At Colgate
# 523498                             France                         via BeBee
# 114666                  Wichita Falls, TX                      via LinkedIn
# 696752                         Orange, CA                         via BeBee
# ...                                   ...                               ...
# 341389                          Singapore                   via Recruit.net
# 70991             New Delhi, Delhi, India       via Boston Consulting Group
# 542527  Taguig, Metro Manila, Philippines                   via Trabajo.org
# 137492             Amsterdam, Netherlands                         via Melga
# 347766        Bengaluru, Karnataka, India  via Careers At Micron Technology
#
#               job_schedule_type  job_work_from_home search_location  \
# 287457                Full-time               False    South Africa
# 129618                Full-time               False           India
# 523498                Full-time               False          France
# 114666  Full-time and Part-time               False         Georgia
# 696752                Full-time               False           Sudan
# ...                         ...                 ...             ...
# 341389                Full-time               False       Singapore
# 70991                 Full-time               False           India
# 542527                Full-time               False     Philippines
# 137492                Full-time               False     Netherlands
# 347766                Full-time               False           India
#
#        job_posted_date  job_no_degree_mention  job_health_insurance  \
# 287457      2023-12-31                  False                 False
# 129618      2023-12-31                  False                 False
# 523498      2023-12-31                  False                 False
# 114666      2023-12-31                  False                  True
# 696752      2023-12-31                  False                  True
# ...                ...                    ...                   ...
# 341389      2023-01-01                  False                 False
# 70991       2023-01-01                  False                 False
# 542527      2023-01-01                  False                 False
# 137492      2023-01-01                  False                 False
# 347766      2023-01-01                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 287457   South Africa        None              NaN              NaN
# 129618          India        None              NaN              NaN
# 523498         France        None              NaN              NaN
# 114666  United States        None              NaN              NaN
# 696752          Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 341389      Singapore        None              NaN              NaN
# 70991           India        None              NaN              NaN
# 542527    Philippines        None              NaN              NaN
# 137492    Netherlands        None              NaN              NaN
# 347766          India        None              NaN              NaN
#
#                           company_name  \
# 287457  DCV Sabenza IT and Recruitment
# 129618       Colgate-Palmolive Company
# 523498                    Darty France
# 114666                    ClickJobs.io
# 696752                    MobilityWare
# ...                                ...
# 341389               Triton AI Pte Ltd
# 70991     BCG, Boston Consulting Group
# 542527                             AIA
# 137492                     Booking.com
# 347766               Micron Technology
#
#                                                job_skills  \
# 287457  ['sql', 'python', 'databricks', 'azure', 'hado...
# 129618  ['python', 'sql', 'gcp', 'snowflake', 'aws', '...
# 523498             ['sql', 'word', 'powerpoint', 'excel']
# 114666  ['python', 'java', 'scala', 'nosql', 'sql', 'm...
# 696752  ['python', 'java', 'c#', 'sql', 'aws', 'snowfl...
# ...                                                   ...
# 341389                      ['oracle', 'tableau', 'word']
# 70991   ['sql', 'python', 'snowflake', 'aws', 'alteryx...
# 542527                                               None
# 137492  ['java', 'scala', 'python', 'perl', 'sql', 'my...
# 347766           ['python', 'snowflake', 'gcp', 'hadoop']
#
#                                           job_type_skills
# 287457  {'analyst_tools': ['ssrs', 'power bi', 'tablea...
# 129618  {'analyst_tools': ['excel'], 'cloud': ['gcp', ...
# 523498  {'analyst_tools': ['word', 'powerpoint', 'exce...
# 114666  {'cloud': ['redshift', 'snowflake', 'aws', 'az...
# 696752  {'cloud': ['aws', 'snowflake', 'gcp'], 'librar...
# ...                                                   ...
# 341389  {'analyst_tools': ['tableau', 'word'], 'cloud'...
# 70991   {'analyst_tools': ['alteryx', 'ssis'], 'cloud'...
# 542527                                               None
# 137492  {'databases': ['mysql', 'cassandra'], 'librari...
# 347766  {'cloud': ['snowflake', 'gcp'], 'libraries': [...
#
# [785741 rows x 17 columns]

# %% [markdown]
# ## Adding a Column
#
# ### Notes
#
# - If you want to create a column you'll need to use the `df['column_name']` syntax.
#
# ### Example
#
# Here we are creating a new column called 'Is Data Analyst' and saying if the column `job_title_short` is equal to 'Data Analyst' then then return 1 if not, return 0. It does this by using `astype(int)`.

# %%
df['Is Data Analyst'] = (df.job_title_short == 'Data Analyst').astype(int)

# %% [markdown]
# Let's view this new column we created.

# %%
df['Is Data Analyst']
# Out:
# 287457    0
# 129618    0
# 523498    1
# 114666    0
# 696752    0
#          ..
# 341389    0
# 70991     0
# 542527    0
# 137492    0
# 347766    0
# Name: Is Data Analyst, Length: 785741, dtype: int64

# %% [markdown]
# Did this work? Let's look at cases when this column is greater than 0, which means it is equal to 1 (aka it's true). We can use our row filtering we learned in the last section.

# %%
df[df['Is Data Analyst'] > 0]
# Out:
#        job_title_short                                          job_title  \
# 523498    Data Analyst                         Data Analyst Transport F/H
# 696478    Data Analyst  Working Student for Voice Assistant Data Annot...
# 621709    Data Analyst                     Business Intelligence Engineer
# 237132    Data Analyst                                       Data Analyst
# 83980     Data Analyst                                       Data analyst
# ...                ...                                                ...
# 341561    Data Analyst                                   GCP Data Analyst
# 443420    Data Analyst                            Commercial Data Analyst
# 220561    Data Analyst  JUNIOR/GRADUATE DATA ANALYST – DEBT AND COLLEC...
# 220269    Data Analyst                                    Jr Data Analyst
# 57877     Data Analyst                                 Data Analyst Dubai
#
#                         job_location           job_via job_schedule_type  \
# 523498                        France         via BeBee         Full-time
# 696478               Berlin, Germany          via XING         Full-time
# 621709                        Greece   via Trabajo.org         Full-time
# 237132                  New York, NY  via ZipRecruiter         Full-time
# 83980                     Dallas, TX    via Talent.com         Full-time
# ...                              ...               ...               ...
# 341561                    Frisco, TX      via LinkedIn        Contractor
# 443420               Nicosia, Cyprus  via BeBee Cyprus         Full-time
# 220561                Nottingham, UK      via LinkedIn         Full-time
# 220269                   Atlanta, GA      via LinkedIn        Contractor
# 57877   Dubai - United Arab Emirates        via Indeed         Full-time
#
#         job_work_from_home          search_location job_posted_date  \
# 523498               False                   France      2023-12-31
# 696478               False                  Germany      2023-12-31
# 621709               False                   Greece      2023-12-31
# 237132               False  New York, United States      2023-12-31
# 83980                False     Texas, United States      2023-12-31
# ...                    ...                      ...             ...
# 341561               False     Texas, United States      2023-01-01
# 443420               False                   Cyprus      2023-01-01
# 220561               False           United Kingdom      2023-01-01
# 220269               False                  Georgia      2023-01-01
# 57877                False     United Arab Emirates      2023-01-01
#
#         job_no_degree_mention  job_health_insurance           job_country  \
# 523498                  False                 False                France
# 696478                  False                 False               Germany
# 621709                   True                 False                Greece
# 237132                  False                 False         United States
# 83980                    True                 False         United States
# ...                       ...                   ...                   ...
# 341561                  False                 False         United States
# 443420                  False                 False                Cyprus
# 220561                   True                 False        United Kingdom
# 220269                  False                 False         United States
# 57877                    True                 False  United Arab Emirates
#
#        salary_rate  salary_year_avg  salary_hour_avg             company_name  \
# 523498        None              NaN              NaN             Darty France
# 696478        None              NaN              NaN             MBition GmbH
# 621709        None              NaN              NaN          Randstad Hellas
# 237132        None              NaN              NaN      Columbia University
# 83980         None              NaN              NaN       Motion Recruitment
# ...            ...              ...              ...                      ...
# 341561        None              NaN              NaN            Micasa Global
# 443420        None              NaN              NaN          GRS Recruitment
# 220561        None              NaN              NaN                  Harnham
# 220269        None              NaN              NaN      RIT Solutions, Inc.
# 57877         None              NaN              NaN  Jobleads-AE/BR/HK/MX/ZA
#
#                                                job_skills  \
# 523498             ['sql', 'word', 'powerpoint', 'excel']
# 696478                                               None
# 621709                                    ['sql', 'ssis']
# 237132                                              ['r']
# 83980                             ['sql', 'azure', 'dax']
# ...                                                   ...
# 341561  ['sql', 'shell', 'gcp', 'bigquery', 'node', 'k...
# 443420                                   ['sql', 'excel']
# 220561                                   ['sql', 'excel']
# 220269  ['go', 'sql', 'word', 'tableau', 'excel', 'flo...
# 57877                                             ['sql']
#
#                                           job_type_skills  Is Data Analyst
# 523498  {'analyst_tools': ['word', 'powerpoint', 'exce...                1
# 696478                                               None                1
# 621709  {'analyst_tools': ['ssis'], 'programming': ['s...                1
# 237132                             {'programming': ['r']}                1
# 83980   {'analyst_tools': ['dax'], 'cloud': ['azure'],...                1
# ...                                                   ...              ...
# 341561  {'cloud': ['gcp', 'bigquery'], 'other': ['kube...                1
# 443420  {'analyst_tools': ['excel'], 'programming': ['...                1
# 220561  {'analyst_tools': ['excel'], 'programming': ['...                1
# 220269  {'analyst_tools': ['word', 'tableau', 'excel']...                1
# 57877                            {'programming': ['sql']}                1
#
# [196075 rows x 18 columns]

# %% [markdown]
# ## Dropping Data
#
# ### Notes
#
# * Use `drop()` if you want to drop (delete) either a column or row in your database.
# * The syntax is:
#     * Drop column: `df.drop('column_name, axis = 1)`
#     * Drop row: `df.drop(index_name, axis = 0)`
# * If you wanted to drop multiple rows you would have the syntax:
#     * Drop multiple columns: `df.drop(['column_name1', 'column_name2'], axis=1)`
#     * Drop multiple rows: `df.drop([index_name1, index_name2], axis=0)`
#
# ### Examples
#
# Let's drop the column `'salary_hour_avg'`, this will have an axis of 1 (since we're dropping a column).

# %%
df.drop('salary_hour_avg', axis = 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-628555668.py in <cell line: 0>()
# ----> 1 df.drop('salary_hour_avg', axis = 1, inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['salary_hour_avg'] not found in axis"

# %% [markdown]
# Inspecting the columns available now:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 287457 to 347766
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
#  14  job_skills             668704 non-null  object
#  15  job_type_skills        668704 non-null  object
#  16  Is Data Analyst        785741 non-null  int64
# dtypes: bool(3), datetime64[ns](1), float64(1), int64(1), object(11)
# memory usage: 92.2+ MB

# %% [markdown]
# This column is now removed!

# %% [markdown]
# ## Remove NA
#
# ### Notes
#
# * To remove rows that contain empty cells use `dropna()`.
# * By default `dropna()` will return a *new* DataFrame, and won't change the original.
#
# ### Example
#
# Let's cleanup our `salary_year_avg` column by removing the `NaN` values in this column.

# %%
df.salary_year_avg.head()
# Out:
# 287457   NaN
# 129618   NaN
# 523498   NaN
# 114666   NaN
# 696752   NaN
# Name: salary_year_avg, dtype: float64

# %%
df.dropna(subset=['salary_year_avg'], inplace=True)

# %%
df.salary_year_avg.head()
# Out:
# 574802     95150.0
# 120858    144000.0
# 122037    137500.0
# 3448      140000.0
# 652503     73000.0
# Name: salary_year_avg, dtype: float64
